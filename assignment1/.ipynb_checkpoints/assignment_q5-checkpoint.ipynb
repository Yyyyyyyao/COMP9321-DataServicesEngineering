# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import sys
import os
import numpy as np
import math

# %%
df5 = pd.read_csv('q2.csv')
df5.drop(['Unnamed: 0'], axis=1, inplace=True)
df5.set_index(['Country'],inplace=True)
df5.sort_index(inplace=True)

# %%
df5
# Out:
#                     GHRP Income classification according to WB  \
# Country
# Afghanistan          Yes                                   LIC
# Albania               No                                   MIC
# Algeria               No                                   MIC
# Angola               Yes                                   MIC
# Antigua and Barbuda   No                                   HIC
# ...                  ...                                   ...
# Venezuela            Yes                                   MIC
# Vietnam               No                                   MIC
# Yemen                Yes                                   LIC
# Zambia               Yes                                   MIC
# Zimbabwe              No                                   MIC
#
#                     Net_ODA_received_perc_of_GNI Aid dependence  \
# Country
# Afghanistan                                19,37            7,2
# Albania                                     1,20            0,0
# Algeria                                     0,11            0,0
# Angola                                      0,19            0,0
# Antigua and Barbuda                         0,69            0,0
# ...                                          ...            ...
# Venezuela                                No data              x
# Vietnam                                     1,12            0,0
# Yemen                                      10,37            2,7
# Zambia                                      4,09            0,0
# Zimbabwe                                    3,61            0,0
#
#                     Volume of remittances in USD as a proportion of total GDP percent 2014-18  \
# Country
# Afghanistan                                                       1,99
# Albania                                                           9,68
# Algeria                                                           1,07
# Angola                                                            0,00
# Antigua and Barbuda                                               2,16
# ...                                                                ...
# Venezuela                                                         0,03
# Vietnam                                                           6,51
# Yemen                                                            12,45
# Zambia                                                            0,40
# Zimbabwe                                                          5,99
#
#                     Remittances  \
# Country
# Afghanistan                 0,0
# Albania                     2,3
# Algeria                     0,0
# Angola                      0,0
# Antigua and Barbuda         0,0
# ...                         ...
# Venezuela                   0,0
# Vietnam                     0,8
# Yemen                       3,7
# Zambia                      0,0
# Zimbabwe                    0,5
#
#                     Food imports percent of total merchandise exports  \
# Country
# Afghanistan                                                      32,3
# Albania                                                          13,5
# Algeria                                                          20,2
# Angola                                                           19,8
# Antigua and Barbuda                                              27,8
# ...                                                               ...
# Venezuela                                                           x
# Vietnam                                                           8,0
# Yemen                                                            46,9
# Zambia                                                            5,3
# Zimbabwe                                                         11,7
#
#                     food import dependence   \
# Country
# Afghanistan                            10,0
# Albania                                 5,4
# Algeria                                 8,1
# Angola                                  7,9
# Antigua and Barbuda                    10,0
# ...                                     ...
# Venezuela                                 x
# Vietnam                                 3,2
# Yemen                                  10,0
# Zambia                                  2,1
# Zimbabwe                                4,7
#
#                     Fuels ores and metals exports percent of total merchandise exports  \
# Country
# Afghanistan                                                       11,6
# Albania                                                            3,7
# Algeria                                                           94,7
# Angola                                                            98,6
# Antigua and Barbuda                                                0,3
# ...                                                                ...
# Venezuela                                                         88,0
# Vietnam                                                            3,1
# Yemen                                                              0,5
# Zambia                                                            78,5
# Zimbabwe                                                          43,3
#
#                     primary commodity export dependence  ...  \
# Country                                                  ...
# Afghanistan                                         1,5  ...
# Albania                                             0,5  ...
# Algeria                                            10,0  ...
# Angola                                             10,0  ...
# Antigua and Barbuda                                 0,0  ...
# ...                                                 ...  ...
# Venezuela                                          10,0  ...
# Vietnam                                             0,4  ...
# Yemen                                               0,1  ...
# Zambia                                             10,0  ...
# Zimbabwe                                            5,8  ...
#
#                     Total reserves in months of imports 2018  \
# Country
# Afghanistan                                            12,19
# Albania                                                 6,37
# Algeria                                                    x
# Angola                                                  5,41
# Antigua and Barbuda                                     3,21
# ...                                                      ...
# Venezuela                                                  x
# Vietnam                                                 2,53
# Yemen                                                      x
# Zambia                                                  1,77
# Zimbabwe                                                   x
#
#                     Foreign currency reserves  \
# Country
# Afghanistan                               0,0
# Albania                                   0,0
# Algeria                                     x
# Angola                                    1,2
# Antigua and Barbuda                       5,6
# ...                                       ...
# Venezuela                                   x
# Vietnam                                   6,9
# Yemen                                       x
# Zambia                                    8,5
# Zimbabwe                                    x
#
#                     Foreign direct investment, net inflows percent of GDP  \
# Country
# Afghanistan                                                       0,62
# Albania                                                           7,97
# Algeria                                                           0,87
# Angola                                                           -5,42
# Antigua and Barbuda                                               8,39
# ...                                                                ...
# Venezuela                                                            x
# Vietnam                                                           6,32
# Yemen                                                            -1,05
# Zambia                                                            1,53
# Zimbabwe                                                          2,40
#
#                     Foreign direct investment  \
# Country
# Afghanistan                               0,2
# Albania                                   3,2
# Algeria                                   0,3
# Angola                                    0,0
# Antigua and Barbuda                       3,4
# ...                                       ...
# Venezuela                                   x
# Vietnam                                   2,5
# Yemen                                     0,0
# Zambia                                    0,6
# Zimbabwe                                  1,0
#
#                     Covid_19_Economic_exposure_index  \
# Country
# Afghanistan                                      2,4
# Albania                                          3,4
# Algeria                                          3,5
# Angola                                           3,8
# Antigua and Barbuda                              4,7
# ...                                              ...
# Venezuela                                        4,3
# Vietnam                                          2,7
# Yemen                                            3,3
# Zambia                                           4,1
# Zimbabwe                                         2,1
#
#                     Covid_19_Economic_exposure_index_Ex_aid_and_FDI  \
# Country
# Afghanistan                                                     2,0
# Albania                                                         4,0
# Algeria                                                         4,8
# Angola                                                          5,0
# Antigua and Barbuda                                             5,7
# ...                                                             ...
# Venezuela                                                       4,3
# Vietnam                                                         3,2
# Yemen                                                           4,1
# Zambia                                                          5,4
# Zimbabwe                                                        2,8
#
#                     Covid_19_Economic_exposure_index_Ex_aid_and_FDI_and_food_import  \
# Country
# Afghanistan                                                        0,4
# Albania                                                            3,7
# Algeria                                                            4,0
# Angola                                                             4,4
# Antigua and Barbuda                                                4,9
# ...                                                                ...
# Venezuela                                                          4,3
# Vietnam                                                            3,2
# Yemen                                                              2,6
# Zambia                                                             6,1
# Zimbabwe                                                           2,3
#
#                                                                 Cities  \
# Country
# Afghanistan          {"Country":"Afghanistan","City":"`Aaqadari Yos...
# Albania              {"Country":"Albania","City":"1 Maj","Latitude"...
# Algeria              {"Country":"Algeria","City":"3 Marabouts","Lat...
# Angola               {"Country":"Angola","City":"1.0 de Maio","Lati...
# Antigua and Barbuda  {"Country":"Antigua and Barbuda","City":"Aberd...
# ...                                                                ...
# Venezuela            {"Country":"Venezuela","City":"1 Beneficio","L...
# Vietnam              {"Country":"Vietnam","City":"A\u00e0m T\u00e2m...
# Yemen                {"Country":"Yemen","City":"Abadila","Latitude"...
# Zambia               {"Country":"Zambia","City":"Aaron","Latitude":...
# Zimbabwe             {"Country":"Zimbabwe","City":"100 Acre Lots","...
#
#                     avg_latitude avg_longitude
# Country
# Afghanistan            34.046741     67.266813
# Albania                41.088976     20.014610
# Algeria                35.602693      3.235778
# Angola                -10.394025     16.401273
# Antigua and Barbuda    17.085519    -61.791439
# ...                          ...           ...
# Venezuela               9.326775    -67.788678
# Vietnam                17.427567    106.246390
# Yemen                  14.588661     45.226203
# Zambia                -13.748025     27.937999
# Zimbabwe              -19.047763     29.515317
#
# [189 rows x 24 columns]

# %%
list(df5)
# Out:
# ['GHRP',
#  'Income classification according to WB',
#  'Net_ODA_received_perc_of_GNI',
#  'Aid dependence',
#  'Volume of remittances in USD as a proportion of total GDP percent 2014-18',
#  'Remittances',
#  'Food imports percent of total merchandise exports',
#  'food import dependence ',
#  'Fuels ores and metals exports percent of total merchandise exports',
#  'primary commodity export dependence',
#  'tourism as percentage of GDP',
#  'tourism dependence',
#  'General government gross debt Percent of GDP 2019',
#  'Government indeptedness',
#  'Total reserves in months of imports 2018',
#  'Foreign currency reserves',
#  'Foreign direct investment, net inflows percent of GDP',
#  'Foreign direct investment',
#  'Covid_19_Economic_exposure_index',
#  'Covid_19_Economic_exposure_index_Ex_aid_and_FDI',
#  'Covid_19_Economic_exposure_index_Ex_aid_and_FDI_and_food_import',
#  'Cities',
#  'avg_latitude',
#  'avg_longitude']

# %%
selected_columns = df5[["Income classification according to WB", "Foreign direct investment", "Net_ODA_received_perc_of_GNI"]]
df5_target=selected_columns.copy()

# %%
df5_target
# Out:
#                     Income classification according to WB  \
# Country
# Afghanistan                                           LIC
# Albania                                               MIC
# Algeria                                               MIC
# Angola                                                MIC
# Antigua and Barbuda                                   HIC
# ...                                                   ...
# Venezuela                                             MIC
# Vietnam                                               MIC
# Yemen                                                 LIC
# Zambia                                                MIC
# Zimbabwe                                              MIC
#
#                     Foreign direct investment Net_ODA_received_perc_of_GNI
# Country
# Afghanistan                               0,2                        19,37
# Albania                                   3,2                         1,20
# Algeria                                   0,3                         0,11
# Angola                                    0,0                         0,19
# Antigua and Barbuda                       3,4                         0,69
# ...                                       ...                          ...
# Venezuela                                   x                      No data
# Vietnam                                   2,5                         1,12
# Yemen                                     0,0                        10,37
# Zambia                                    0,6                         4,09
# Zimbabwe                                  1,0                         3,61
#
# [189 rows x 3 columns]

# %%
df5_target.replace('x', np.nan, regex=True, inplace=True)
df5_target.replace('No data', np.nan, regex=True, inplace=True)

# %%
df5_target
# Out:
#                     Income classification according to WB  \
# Country
# Afghanistan                                           LIC
# Albania                                               MIC
# Algeria                                               MIC
# Angola                                                MIC
# Antigua and Barbuda                                   HIC
# ...                                                   ...
# Venezuela                                             MIC
# Vietnam                                               MIC
# Yemen                                                 LIC
# Zambia                                                MIC
# Zimbabwe                                              MIC
#
#                     Foreign direct investment Net_ODA_received_perc_of_GNI
# Country
# Afghanistan                               0,2                        19,37
# Albania                                   3,2                         1,20
# Algeria                                   0,3                         0,11
# Angola                                    0,0                         0,19
# Antigua and Barbuda                       3,4                         0,69
# ...                                       ...                          ...
# Venezuela                                 NaN                          NaN
# Vietnam                                   2,5                         1,12
# Yemen                                     0,0                        10,37
# Zambia                                    0,6                         4,09
# Zimbabwe                                  1,0                         3,61
#
# [189 rows x 3 columns]

# %%
df5_target.dropna()
# Out:
#                     Income classification according to WB  \
# Country
# Afghanistan                                           LIC
# Albania                                               MIC
# Algeria                                               MIC
# Angola                                                MIC
# Antigua and Barbuda                                   HIC
# ...                                                   ...
# Vanuatu                                               MIC
# Vietnam                                               MIC
# Yemen                                                 LIC
# Zambia                                                MIC
# Zimbabwe                                              MIC
#
#                     Foreign direct investment Net_ODA_received_perc_of_GNI
# Country
# Afghanistan                               0,2                        19,37
# Albania                                   3,2                         1,20
# Algeria                                   0,3                         0,11
# Angola                                    0,0                         0,19
# Antigua and Barbuda                       3,4                         0,69
# ...                                       ...                          ...
# Vanuatu                                   1,6                        15,49
# Vietnam                                   2,5                         1,12
# Yemen                                     0,0                        10,37
# Zambia                                    0,6                         4,09
# Zimbabwe                                  1,0                         3,61
#
# [128 rows x 3 columns]

# %%
df5_target.replace(',', '.', regex=True, inplace=True)

# %%
df5_target["Foreign direct investment"] = pd.to_numeric(df5_target["Foreign direct investment"])
df5_target["Net_ODA_received_perc_of_GNI"] = pd.to_numeric(df5_target["Net_ODA_received_perc_of_GNI"])
df5_target.rename(columns={"Income classification according to WB": "Income Class", "Foreign direct investment":"Avg Foreign direct investment", "Net_ODA_received_perc_of_GNI": "Avg_Net_ODA_received_perc_of_GNI"}, inplace=True)

df5_result = df5_target.groupby(["Income Class"])['Avg Foreign direct investment', 'Avg_Net_ODA_received_perc_of_GNI'].agg('mean')

# df_final = df_result.groupby(["Continent"])['Covid_19_Economic_exposure_index'].agg('mean').reset_index()
# Out:
# <ipython-input-21-517f513767fb>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df5_result = df5_target.groupby(["Income Class"])['Avg Foreign direct investment', 'Avg_Net_ODA_received_perc_of_GNI'].agg('mean')

# %%
df5_result
# Out:
#               Avg Foreign direct investment  Avg_Net_ODA_received_perc_of_GNI
# Income Class
# HIC                                1.511111                          1.685000
# LIC                                1.937037                         11.773704
# MIC                                1.417172                          3.934898

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-27bb4cd021cd> in <module>
# ----> 1 df5 = df5_result.set_index(['Income Class'])
#
# /Applications/anaconda3/envs/COMP9321/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['Income Class'] are in the columns"

# %%
# Out:
#                                        Avg Foreign direct investment  \
# Income classification according to WB
# HIC                                                         1.511111
# LIC                                                         1.937037
# MIC                                                         1.417172
#
#                                        Avg_Net_ODA_received_perc_of_GNI
# Income classification according to WB
# HIC                                                            1.685000
# LIC                                                           11.773704
# MIC                                                            3.934898
